# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('TaxiFare.csv')
df.shape
# Out:
# (50000, 8)

# %%
df.head(2)
# Out:
#   unique_id  amount      date_time_of_pickup  longitude_of_pickup  \
# 0   26:21.0     4.5  2009-06-15 17:26:21 UTC           -73.844311
# 1   52:16.0    16.9  2010-01-05 16:52:16 UTC           -74.016048
#
#    latitude_of_pickup  longitude_of_dropoff  latitude_of_dropoff  \
# 0           40.721319            -73.841610            40.712278
# 1           40.711303            -73.979268            40.782004
#
#    no_of_passenger
# 0                1
# 1                1

# %%
df.columns = ['id','amount','datetime','lon_pickup','lat_pickup',
              'lon_drop','lat_drop','passcount']
df.head()
# Out:
#         id  amount                 datetime  lon_pickup  lat_pickup  \
# 0  26:21.0     4.5  2009-06-15 17:26:21 UTC  -73.844311   40.721319
# 1  52:16.0    16.9  2010-01-05 16:52:16 UTC  -74.016048   40.711303
# 2  35:00.0     5.7  2011-08-18 00:35:00 UTC  -73.982738   40.761270
# 3  30:42.0     7.7  2012-04-21 04:30:42 UTC  -73.987130   40.733143
# 4  51:00.0     5.3  2010-03-09 07:51:00 UTC  -73.968095   40.768008
#
#     lon_drop   lat_drop  passcount
# 0 -73.841610  40.712278          1
# 1 -73.979268  40.782004          1
# 2 -73.991242  40.750562          2
# 3 -73.991567  40.758092          1
# 4 -73.956655  40.783762          1

# %%
df.isnull().sum()
# Out:
# id            0
# amount        0
# datetime      0
# lon_pickup    0
# lat_pickup    0
# lon_drop      0
# lat_drop      0
# passcount     0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.dtypes
# Out:
# id             object
# amount        float64
# datetime       object
# lon_pickup    float64
# lat_pickup    float64
# lon_drop      float64
# lat_drop      float64
# passcount       int64
# dtype: object

# %%
df['datetime'] = pd.to_datetime(df['datetime'])

# %%
df.dtypes
# Out:
# id                         object
# amount                    float64
# datetime      datetime64[ns, UTC]
# lon_pickup                float64
# lat_pickup                float64
# lon_drop                  float64
# lat_drop                  float64
# passcount                   int64
# dtype: object

# %% [markdown]
# #### Feature Engineering

# %%
df['Yr'] = df['datetime'].dt.year
df['Qtr'] = df['datetime'].dt.quarter
df['Month'] = df['datetime'].dt.month
df['Day'] = df['datetime'].dt.day
df['Hour'] = df['datetime'].dt.hour
df['DayofWeek'] = df['datetime'].dt.weekday
df.head()
# Out:
#         id  amount                  datetime  lon_pickup  lat_pickup  \
# 0  26:21.0     4.5 2009-06-15 17:26:21+00:00  -73.844311   40.721319
# 1  52:16.0    16.9 2010-01-05 16:52:16+00:00  -74.016048   40.711303
# 2  35:00.0     5.7 2011-08-18 00:35:00+00:00  -73.982738   40.761270
# 3  30:42.0     7.7 2012-04-21 04:30:42+00:00  -73.987130   40.733143
# 4  51:00.0     5.3 2010-03-09 07:51:00+00:00  -73.968095   40.768008
#
#     lon_drop   lat_drop  passcount    Yr  Qtr  Month  Day  Hour  DayofWeek
# 0 -73.841610  40.712278          1  2009    2      6   15    17          0
# 1 -73.979268  40.782004          1  2010    1      1    5    16          1
# 2 -73.991242  40.750562          2  2011    3      8   18     0          3
# 3 -73.991567  40.758092          1  2012    2      4   21     4          5
# 4 -73.956655  40.783762          1  2010    1      3    9     7          1

# %%
df['DayofWeek'].value_counts()
# Out:
# DayofWeek
# 4    7668
# 5    7630
# 3    7406
# 2    7212
# 1    6927
# 0    6639
# 6    6518
# Name: count, dtype: int64

# %%
# Weekend = 1, Weekday = 0
df['IsWeekend'] = np.where(df['DayofWeek'].isin([5,6]),1,0)

# %%
df.head()
# Out:
#         id  amount                  datetime  lon_pickup  lat_pickup  \
# 0  26:21.0     4.5 2009-06-15 17:26:21+00:00  -73.844311   40.721319
# 1  52:16.0    16.9 2010-01-05 16:52:16+00:00  -74.016048   40.711303
# 2  35:00.0     5.7 2011-08-18 00:35:00+00:00  -73.982738   40.761270
# 3  30:42.0     7.7 2012-04-21 04:30:42+00:00  -73.987130   40.733143
# 4  51:00.0     5.3 2010-03-09 07:51:00+00:00  -73.968095   40.768008
#
#     lon_drop   lat_drop  passcount    Yr  Qtr  Month  Day  Hour  DayofWeek  \
# 0 -73.841610  40.712278          1  2009    2      6   15    17          0
# 1 -73.979268  40.782004          1  2010    1      1    5    16          1
# 2 -73.991242  40.750562          2  2011    3      8   18     0          3
# 3 -73.991567  40.758092          1  2012    2      4   21     4          5
# 4 -73.956655  40.783762          1  2010    1      3    9     7          1
#
#    IsWeekend
# 0          0
# 1          0
# 2          0
# 3          1
# 4          0

# %%
df['Hour'].unique()
# Out:
# array([17, 16,  0,  4,  7,  9, 20, 13,  1, 11, 19, 12, 14, 18, 15,  6, 21,
#        23,  3,  8, 10,  2, 22,  5])

# %%
def compute_hr_qtr(x):
    if x>0 and x<=6:   # Night
        return 1
    elif x>6 and x<=12 : # Morning
        return 2
    elif x>12 and x<=18: # Afternoon
        return 3
    else:
        return 4       # Evening

# %%
df['Hr_Qtr'] = df['Hour'].apply(compute_hr_qtr)

# %%
df['Hr_Qtr'].value_counts(dropna=False)
# Out:
# Hr_Qtr
# 4    15959
# 3    14913
# 2    13574
# 1     5554
# Name: count, dtype: int64

# %%
df['Hr_Qtr1'] = pd.cut(df['Hour'],bins=[0,6,12,18,23],labels=[1,2,3,4])
df['Hr_Qtr1'].value_counts(dropna=False)
# Out:
# Hr_Qtr1
# 3      14913
# 4      14069
# 2      13574
# 1       5554
# NaN     1890
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['id', 'amount', 'datetime', 'lon_pickup', 'lat_pickup', 'lon_drop',
#        'lat_drop', 'passcount', 'Yr', 'Qtr', 'Month', 'Day', 'Hour',
#        'DayofWeek', 'IsWeekend', 'Hr_Qtr', 'Hr_Qtr1'],
#       dtype='object')

# %%
# from pandas.tseries.holiday import USFederalHolidayCalendar as calendar

# %%
# print(df['datetime'].min(),df['datetime'].max())

# %%
# cal = calendar()
# holidays = cal.holidays(start=df['datetime'].min(), end=df['datetime'].max())

# df['Holiday'] = df['datetime'].isin(holidays)
# df['Holiday'].value_counts()

# %% [markdown]
# #### Check data consistency

# %%
df.describe()
# Out:
#              amount    lon_pickup    lat_pickup      lon_drop      lat_drop  \
# count  50000.000000  50000.000000  50000.000000  50000.000000  50000.000000
# mean      11.364171    -72.509756     39.933759    -72.504616     39.926251
# std        9.685557     10.393860      6.224857     10.407570      6.014737
# min       -5.000000    -75.423848    -74.006893    -84.654241    -74.006377
# 25%        6.000000    -73.992062     40.734880    -73.991152     40.734372
# 50%        8.500000    -73.981840     40.752678    -73.980082     40.753372
# 75%       12.500000    -73.967148     40.767360    -73.963584     40.768167
# max      200.000000     40.783472    401.083332     40.851027     43.415190
#
#           passcount            Yr           Qtr         Month           Day  \
# count  50000.000000  50000.000000  50000.000000  50000.000000  50000.000000
# mean       1.667840   2011.739260      2.422800      6.273300     15.672040
# std        1.289195      1.862639      1.121528      3.461157      8.660789
# min        0.000000   2009.000000      1.000000      1.000000      1.000000
# 25%        1.000000   2010.000000      1.000000      3.000000      8.000000
# 50%        1.000000   2012.000000      2.000000      6.000000     16.000000
# 75%        2.000000   2013.000000      3.000000      9.000000     23.000000
# max        6.000000   2015.000000      4.000000     12.000000     31.000000
#
#                Hour     DayofWeek     IsWeekend        Hr_Qtr
# count  50000.000000  50000.000000  50000.000000  50000.000000
# mean      13.489080      3.029980      0.282960      2.825540
# std        6.506935      1.956936      0.450442      1.002279
# min        0.000000      0.000000      0.000000      1.000000
# 25%        9.000000      1.000000      0.000000      2.000000
# 50%       14.000000      3.000000      0.000000      3.000000
# 75%       19.000000      5.000000      1.000000      4.000000
# max       23.000000      6.000000      1.000000      4.000000

# %%
print(df[df['amount']<=0].shape)
print(df[df['passcount']==0].shape)
# Out:
# (9, 17)
# (165, 17)

# %%
df1 = df.copy()

# %%
df = df[df['amount']>0]
print(df.shape)
# Out:
# (49991, 17)

# %%
df = df[df['passcount']!=0]
df.shape
# Out:
# (49826, 17)

# %% [markdown]
# #### Note
# 1) Latitude ranges from -90 to 90<br>
# 2) Logitude ranges from -180 to 180<br>

# %%
print(df[(df['lat_pickup']<=-90) | (df['lat_pickup']>90)].shape)
print(df[(df['lat_drop']<=-90) | (df['lat_drop']>90)].shape)
# Out:
# (1, 17)
# (0, 17)

# %%
print(df[(df['lon_pickup']<=-180) | (df['lon_pickup']>180)].shape)
print(df[(df['lon_drop']<=-180) | (df['lon_drop']>180)].shape)
# Out:
# (0, 17)
# (0, 17)

# %%
df[(df['lat_pickup']<=-90) | (df['lat_pickup']>90)]
# Out:
#            id  amount                  datetime  lon_pickup  lat_pickup  \
# 5686  15:00.0     3.3 2011-07-30 11:15:00+00:00  -73.947235  401.083332
#
#        lon_drop   lat_drop  passcount    Yr  Qtr  Month  Day  Hour  DayofWeek  \
# 5686 -73.951392  40.778927          1  2011    3      7   30    11          5
#
#       IsWeekend  Hr_Qtr Hr_Qtr1
# 5686          1       2       2

# %%
df = df[(df['lat_pickup']>=-90) & (df['lat_pickup']<=90)]
df.shape
# Out:
# (49825, 17)

# %% [markdown]
# #### Treating Outliers in Lat and Lon

# %%
a1 = df.describe(percentiles=[0.01,0.02,0.05,0.95,0.98,0.99]).T
a1 = a1.iloc[:,3:]
a1
# Out:
#                     min           1%           2%           5%          50%  \
# amount         0.010000     3.300000     3.500000     4.100000     8.500000
# lon_pickup   -75.423848   -74.014445   -74.010464   -74.006819   -73.981838
# lat_pickup   -74.006893     0.000000    40.583785    40.702190    40.752685
# lon_drop     -84.654241   -74.015120   -74.011760   -74.007273   -73.980087
# lat_drop     -74.006377     0.000000    40.572868    40.686191    40.753375
# passcount      1.000000     1.000000     1.000000     1.000000     1.000000
# Yr          2009.000000  2009.000000  2009.000000  2009.000000  2012.000000
# Qtr            1.000000     1.000000     1.000000     1.000000     2.000000
# Month          1.000000     1.000000     1.000000     1.000000     6.000000
# Day            1.000000     1.000000     1.000000     2.000000    16.000000
# Hour           0.000000     0.000000     0.000000     1.000000    14.000000
# DayofWeek      0.000000     0.000000     0.000000     0.000000     3.000000
# IsWeekend      0.000000     0.000000     0.000000     0.000000     0.000000
# Hr_Qtr         1.000000     1.000000     1.000000     1.000000     3.000000
#
#                     95%          98%          99%          max
# amount        30.500000    46.815600    52.000000   200.000000
# lon_pickup   -73.871363   -73.239712     0.000000    40.783472
# lat_pickup    40.787791    40.799559    40.807074    43.098708
# lon_drop     -73.873373   -73.474126     0.000000    40.851027
# lat_drop      40.794042    40.810229    40.832378    43.415190
# passcount      5.000000     5.000000     6.000000     6.000000
# Yr          2015.000000  2015.000000  2015.000000  2015.000000
# Qtr            4.000000     4.000000     4.000000     4.000000
# Month         12.000000    12.000000    12.000000    12.000000
# Day           29.000000    30.000000    31.000000    31.000000
# Hour          22.000000    23.000000    23.000000    23.000000
# DayofWeek      6.000000     6.000000     6.000000     6.000000
# IsWeekend      1.000000     1.000000     1.000000     1.000000
# Hr_Qtr         4.000000     4.000000     4.000000     4.000000

# %%
print(df[df['lat_pickup']==0].shape)
print(df[df['lat_drop']==0].shape)
print(df[df['lon_pickup']==0].shape)
print(df[df['lon_drop']==0].shape)
# Out:
# (951, 17)
# (950, 17)
# (951, 17)
# (953, 17)

# %%
print(df[(df['lat_pickup']==0) & (df['lon_pickup']==0)].shape)
# Out:
# (949, 17)

# %%
print(df[df['lat_pickup']<40.583785].shape)
# Out:
# (997, 17)

# %%
df['lat_pickup'] = np.where(df['lat_pickup']<40.583785,40.583785,df['lat_pickup'])  # 2%ile
df['lat_drop'] = np.where(df['lat_drop']<40.572868,40.572868,df['lat_drop'])        # 2%ile
df['lon_pickup'] = np.where(df['lon_pickup']>-73.239712,-73.239712,df['lon_pickup']) # 98%ile
df['lon_drop'] = np.where(df['lon_drop']>-73.474126,-73.474126,df['lon_drop'])     # 98%ile

# %%
a1 = df.describe(percentiles=[0.01,0.02,0.05,0.95,0.98,0.99]).T
a1 = a1.iloc[:,3:]
a1
# Out:
#                     min           1%           2%           5%          50%  \
# amount         0.010000     3.300000     3.500000     4.100000     8.500000
# lon_pickup   -75.423848   -74.014445   -74.010464   -74.006819   -73.981838
# lat_pickup    40.583785    40.583785    40.585624    40.702190    40.752685
# lon_drop     -84.654241   -74.015120   -74.011760   -74.007273   -73.980087
# lat_drop      40.572868    40.572868    40.573724    40.686191    40.753375
# passcount      1.000000     1.000000     1.000000     1.000000     1.000000
# Yr          2009.000000  2009.000000  2009.000000  2009.000000  2012.000000
# Qtr            1.000000     1.000000     1.000000     1.000000     2.000000
# Month          1.000000     1.000000     1.000000     1.000000     6.000000
# Day            1.000000     1.000000     1.000000     2.000000    16.000000
# Hour           0.000000     0.000000     0.000000     1.000000    14.000000
# DayofWeek      0.000000     0.000000     0.000000     0.000000     3.000000
# IsWeekend      0.000000     0.000000     0.000000     0.000000     0.000000
# Hr_Qtr         1.000000     1.000000     1.000000     1.000000     3.000000
#
#                     95%          98%          99%          max
# amount        30.500000    46.815600    52.000000   200.000000
# lon_pickup   -73.871363   -73.292918   -73.239712   -73.239712
# lat_pickup    40.787791    40.799559    40.807074    43.098708
# lon_drop     -73.873373   -73.493118   -73.474126   -73.474126
# lat_drop      40.794042    40.810229    40.832378    43.415190
# passcount      5.000000     5.000000     6.000000     6.000000
# Yr          2015.000000  2015.000000  2015.000000  2015.000000
# Qtr            4.000000     4.000000     4.000000     4.000000
# Month         12.000000    12.000000    12.000000    12.000000
# Day           29.000000    30.000000    31.000000    31.000000
# Hour          22.000000    23.000000    23.000000    23.000000
# DayofWeek      6.000000     6.000000     6.000000     6.000000
# IsWeekend      1.000000     1.000000     1.000000     1.000000
# Hr_Qtr         4.000000     4.000000     4.000000     4.000000

# %%
#### Taxi Fare => Distance + PassCount, CarType, Day, Time,

# %% [markdown]
# #### Distance Metrics
# A(x1,y1), B(x2,y2)
# <pre>
# 1) Minkowski Distance(A,B) = ((|x2-x1|)^p + (|y2-y1|)^p) ^(1/p), p is an int
#
# If p = 2
# 2) Euclidean Distance(A,B) = sqrt((x2-x1)^2 + (y2-y1)^2))
# If p = 1
# 3) Manhattan Distance(A,B) = (|x2-x1|) + (|y2-y1|)
# </pre>

# %%
df.columns
# Out:
# Index(['id', 'amount', 'datetime', 'lon_pickup', 'lat_pickup', 'lon_drop',
#        'lat_drop', 'passcount', 'Yr', 'Qtr', 'Month', 'Day', 'Hour',
#        'DayofWeek', 'IsWeekend', 'Hr_Qtr', 'Hr_Qtr1'],
#       dtype='object')

# %%
def minkowski_dist(x1,x2,y1,y2,p):
    dist  = ((abs(x2-x1))**p + (abs(y2-y1))**p)**(1/p)
    return dist

# %%
df['Euclidean_Dist'] = minkowski_dist(df['lat_pickup'],df['lat_drop'],
                                     df['lon_pickup'],df['lon_drop'],2)

df['Manhattan_Dist'] = minkowski_dist(df['lat_pickup'],df['lat_drop'],
                                     df['lon_pickup'],df['lon_drop'],1)

# %% [markdown]
# ### Haversine Distance

# %%
from sklearn.metrics.pairwise import haversine_distances
from math import radians

# %%
def generate_haversine():
    hav_dis = []
    for i in range(len(df)):
        lat_pair_r = [radians(df['lat_pickup'].iloc[i]),
                    radians(df['lon_pickup'].iloc[i])]
        lon_pair_r = [radians(df['lat_drop'].iloc[i]),
                    radians(df['lon_drop'].iloc[i])]
        res = (haversine_distances([lat_pair_r, lon_pair_r])*6371)[0][1]
        # radius of earth = 6371 kms
        hav_dis.append(res)
    return hav_dis

# %%
df['Haversine_Dist'] = generate_haversine()

# %%
df.head()
# Out:
#         id  amount                  datetime  lon_pickup  lat_pickup  \
# 0  26:21.0     4.5 2009-06-15 17:26:21+00:00  -73.844311   40.721319
# 1  52:16.0    16.9 2010-01-05 16:52:16+00:00  -74.016048   40.711303
# 2  35:00.0     5.7 2011-08-18 00:35:00+00:00  -73.982738   40.761270
# 3  30:42.0     7.7 2012-04-21 04:30:42+00:00  -73.987130   40.733143
# 4  51:00.0     5.3 2010-03-09 07:51:00+00:00  -73.968095   40.768008
#
#     lon_drop   lat_drop  passcount    Yr  Qtr  Month  Day  Hour  DayofWeek  \
# 0 -73.841610  40.712278          1  2009    2      6   15    17          0
# 1 -73.979268  40.782004          1  2010    1      1    5    16          1
# 2 -73.991242  40.750562          2  2011    3      8   18     0          3
# 3 -73.991567  40.758092          1  2012    2      4   21     4          5
# 4 -73.956655  40.783762          1  2010    1      3    9     7          1
#
#    IsWeekend  Hr_Qtr Hr_Qtr1  Euclidean_Dist  Manhattan_Dist  Haversine_Dist
# 0          0       3       3        0.009436        0.011742        1.030764
# 1          0       3       3        0.079696        0.107481        8.450134
# 2          0       4     NaN        0.013674        0.019212        1.389525
# 3          1       1       1        0.025340        0.029386        2.799270
# 4          0       2       2        0.019470        0.027194        1.999157

# %%
# !pip install folium

# %%
import folium
from folium import Marker

# %%
# Map([lat,long])
map1 = folium.Map([40.721319,-73.844311],tiles='openstreetmap')
map1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f3bcf9aec4ba461bf75979352852d0bd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f3bcf9aec4ba461bf75979352852d0bd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f3bcf9aec4ba461bf75979352852d0bd = L.map(
#                 &quot;map_f3bcf9aec4ba461bf75979352852d0bd&quot;,
#                 {
#                     center: [40.721319, -73.844311],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b8088bab5e20a57a3948b6c52fa534f5 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b8088bab5e20a57a3948b6c52fa534f5.addTo(map_f3bcf9aec4ba461bf75979352852d0bd);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
samp = df.sample(50)
samp.shape
# Out:
# (50, 20)

# %%
# df.columns

# %%
lat1 = samp['lat_pickup']
lon1 = samp['lon_pickup']
lat2 = samp['lat_drop']
lon2 = samp['lon_drop']

# %% [markdown]
# #### Pickup Locations

# %%
for i,j in zip(lat1,lon1):
    folium.Marker(location=[i,j],tooltip=f"{str(i)} {str(j)}",
                  icon=folium.Icon(color='red')).add_to(map1)
    
map1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f3bcf9aec4ba461bf75979352852d0bd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f3bcf9aec4ba461bf75979352852d0bd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f3bcf9aec4ba461bf75979352852d0bd = L.map(
#                 &quot;map_f3bcf9aec4ba461bf75979352852d0bd&quot;,
#                 {
#                     center: [40.721319, -73.844311],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b8088bab5e20a57a3948b6c52fa534f5 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b8088bab5e20a57a3948b6c52fa534f5.addTo(map_f3bcf9aec4ba461bf75979352852d0bd);
#
#
#             tile_layer_b8088bab5e20a57a3948b6c52fa534f5.addTo(map_f3bcf9aec4ba461bf75979352852d0bd);
#
#
#             var marker_597163335155aacd65cab45f5200cd8c = L.marker(
#                 [40.583785, -73.239712],
#                 {
# }
#             ).addTo(map_f3bcf9aec4ba461bf75979352852d0bd);
#
#
#             var icon_a53c8c0e9bb8548abd757659d4156e1e = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_597163335155aacd65cab45f5200cd8c.setIcon(icon_a53c8c0e9bb8548abd757659d4156e1e);
#
#
#             marker_597163335155aacd65cab45f5200cd8c.bindTooltip(
#                 `&lt;div&gt;
#                      40.583785 -73.239712
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_451ba97311938d4fd4275fa34ebb76c4 = L.marker(
#                 [40.741693, -73.993871],
#                 {
# }
#             ).addTo(map_f3bcf9aec4ba461bf75979352852d0bd);
#
#
#             var icon_44228a20c2435b3957af31c54209074b = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_451ba97311938d4fd4275fa34ebb76c4.setIcon(icon_44228a20c2435b3957af31c54209074b);
#
#
#             marker_451ba97311938d4fd4275fa34ebb76c4.bindTooltip(
#                 `&lt;div&gt;
#                      40.741693 -73.993871
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_0a8af3337626b79029c74e782dc05eaa = L.marker(
#                 [40.72016907, -74.00856781],
#                 {
# }
#             ).addTo(map_f3bcf9aec4ba461bf75979352852d0bd);
#
#
#             var icon_84299930d2320d5e0407ab8b26ff3736 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_0a8af3337626b79029c74e782dc05eaa.setIcon(icon_84299930d2320d5e0407ab8b26ff3736);
#
#
#             marker_0a8af3337626b79029c74e782dc05eaa.bindTooltip(
#                 `&lt;div&gt;
#                      40.72016907 -74.00856781
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_f41aec0ca787f8cd504ab645c5ccad84 = L.marker(
#                 [40.755273, -73.968208],
#                 {
# }
#             ).addTo(map_f3bcf9aec4ba461bf75979352852d0bd);
#
#
#             var icon_3d2de451dec7fbc31104f0aceec2a267 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_f41aec0ca787f8cd504ab645c5ccad84.setIcon(icon_3d2de451dec7fbc31104f0aceec2a267);
#
#
#             marker_f41aec0ca787f8cd504ab645c5ccad84.bindTooltip(
#                 `&lt;div&gt;
#                      40.755273 -73.968208
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_4822ff12fd8cff14ed4c0060234553be = L.marker(
#                 [40.767133, -73.98181],
#                 {
# }
#             ).addTo(map_f3bcf9aec4ba461bf75979352852d0bd);
#
#
#             var icon_d79f3811ca142ff4714273d5b4389aab = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;

# %% [markdown]
# #### Drop Location

# %%
for i,j in zip(lat2,lon2):
    folium.Marker(location=[i,j],tooltip=f"{str(i)} {str(j)}",
                  icon=folium.Icon(color='black')).add_to(map1)
    
map1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f3bcf9aec4ba461bf75979352852d0bd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f3bcf9aec4ba461bf75979352852d0bd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f3bcf9aec4ba461bf75979352852d0bd = L.map(
#                 &quot;map_f3bcf9aec4ba461bf75979352852d0bd&quot;,
#                 {
#                     center: [40.721319, -73.844311],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b8088bab5e20a57a3948b6c52fa534f5 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b8088bab5e20a57a3948b6c52fa534f5.addTo(map_f3bcf9aec4ba461bf75979352852d0bd);
#
#
#             tile_layer_b8088bab5e20a57a3948b6c52fa534f5.addTo(map_f3bcf9aec4ba461bf75979352852d0bd);
#
#
#             var marker_597163335155aacd65cab45f5200cd8c = L.marker(
#                 [40.583785, -73.239712],
#                 {
# }
#             ).addTo(map_f3bcf9aec4ba461bf75979352852d0bd);
#
#
#             var icon_a53c8c0e9bb8548abd757659d4156e1e = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_597163335155aacd65cab45f5200cd8c.setIcon(icon_a53c8c0e9bb8548abd757659d4156e1e);
#
#
#             marker_597163335155aacd65cab45f5200cd8c.bindTooltip(
#                 `&lt;div&gt;
#                      40.583785 -73.239712
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_451ba97311938d4fd4275fa34ebb76c4 = L.marker(
#                 [40.741693, -73.993871],
#                 {
# }
#             ).addTo(map_f3bcf9aec4ba461bf75979352852d0bd);
#
#
#             var icon_44228a20c2435b3957af31c54209074b = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_451ba97311938d4fd4275fa34ebb76c4.setIcon(icon_44228a20c2435b3957af31c54209074b);
#
#
#             marker_451ba97311938d4fd4275fa34ebb76c4.bindTooltip(
#                 `&lt;div&gt;
#                      40.741693 -73.993871
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_0a8af3337626b79029c74e782dc05eaa = L.marker(
#                 [40.72016907, -74.00856781],
#                 {
# }
#             ).addTo(map_f3bcf9aec4ba461bf75979352852d0bd);
#
#
#             var icon_84299930d2320d5e0407ab8b26ff3736 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_0a8af3337626b79029c74e782dc05eaa.setIcon(icon_84299930d2320d5e0407ab8b26ff3736);
#
#
#             marker_0a8af3337626b79029c74e782dc05eaa.bindTooltip(
#                 `&lt;div&gt;
#                      40.72016907 -74.00856781
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_f41aec0ca787f8cd504ab645c5ccad84 = L.marker(
#                 [40.755273, -73.968208],
#                 {
# }
#             ).addTo(map_f3bcf9aec4ba461bf75979352852d0bd);
#
#
#             var icon_3d2de451dec7fbc31104f0aceec2a267 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_f41aec0ca787f8cd504ab645c5ccad84.setIcon(icon_3d2de451dec7fbc31104f0aceec2a267);
#
#
#             marker_f41aec0ca787f8cd504ab645c5ccad84.bindTooltip(
#                 `&lt;div&gt;
#                      40.755273 -73.968208
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_4822ff12fd8cff14ed4c0060234553be = L.marker(
#                 [40.767133, -73.98181],
#                 {
# }
#             ).addTo(map_f3bcf9aec4ba461bf75979352852d0bd);
#
#
#             var icon_d79f3811ca142ff4714273d5b4389aab = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;

# %%
# pickup -> drop
# (lat1,lon1) -> (lat2,lon2)

# %%
data = []
for lt1,ln1,lt2,ln2 in zip(lat1,lon1,lat2,lon2):
    data.append([[lt1,ln1],[lt2,ln2]])
data
# Out:
# [[[40.583785, -73.239712], [40.572868, -73.474126]],
#  [[40.741693, -73.993871], [40.726868, -74.000985]],
#  [[40.72016907, -74.00856781], [40.7213707, -73.98828125]],
#  [[40.755273, -73.968208], [40.749675, -73.987495]],
#  [[40.767133, -73.98181], [40.777967, -73.961992]],
#  [[40.76574, -73.98278], [40.773368, -73.977918]],
#  [[40.782701, -73.957355], [40.783689, -73.974275]],
#  [[40.805725, -73.956202], [40.797615, -73.964115]],
#  [[40.761382, -73.968997], [40.741472, -73.979652]],
#  [[40.767291, -73.956328], [40.73349, -74.002683]],
#  [[40.752195, -74.00456], [40.751282, -73.991126]],
#  [[40.761094, -73.979465], [40.750058, -73.991294]],
#  [[40.754175, -73.969156], [40.751177, -73.990866]],
#  [[40.774037, -73.95129], [40.717092, -73.994375]],
#  [[40.740823, -74.001799], [40.753446, -73.992059]],
#  [[40.728703, -73.987643], [40.726975, -74.000913]],
#  [[40.763238, -73.997935], [40.787403, -73.952535]],
#  [[40.764317, -73.98844], [40.761187, -73.962075]],
#  [[40.768418, -73.982139], [40.773796, -73.958539]],
#  [[40.709402, -74.015133], [40.768155, -73.861477]],
#  [[40.733373, -73.990882], [40.73749, -73.953784]],
#  [[40.754926, -73.965193], [40.761741, -73.970183]],
#  [[40.751017, -73.975342], [40.785733, -73.972422]],
#  [[40.827767, -73.949716], [40.823235, -73.954649]],
#  [[40.720245, -73.989595], [40.741682, -73.982212]],
#  [[40.759138, -73.976443], [40.729878, -74.004093]],
#  [[40.763477, -73.971667], [40.759477, -73.989658]],
#  [[40.746531, -73.979838], [40.775126, -73.98794]],
#  [[40.754547, -73.972033], [40.751925, -73.968415]],
#  [[40.719847, -74.002402], [40.750665, -73.994592]],
#  [[40.74209213, -73.992836], [40.77715683, -73.95866394]],
#  [[40.78461, -73.977218], [40.795115, -73.970685]],
#  [[40.714482, -74.009885], [40.710655, -73.987608]],
#  [[40.786312, -73.978987], [40.760492, -73.981887]],
#  [[40.749672, -73.983306], [40.704519, -74.00989]],
#  [[40.735271, -73.991907], [40.789187, -73.97084]],
#  [[40.760202, -73.983806], [40.749288, -73.99187]],
#  [[40.720247, -73.988732], [40.716056, -73.998186]],
#  [[40.7532, -73.97857], [40.76608, -73.98697]],
#  [[40.764209, -73.986845], [40.762559, -73.985898]],
#  [[40.751998, -73.975578], [40.736068, -73.985098]],
#  [[40.767866, -73.953202], [40.772247, -73.952347]],
#  [[40.778151, -73.952695], [40.777373, -73.960255]],
#  [[40.797272, -73.968037], [40.774978, -73.985318]],
#  [[40.73921, -73.995673], [40.723612, -73.998087]],
#  [[40.770947, -73.950827], [40.757422, -73.968523]],
#  [[40.777652, -73.950997], [40.769082, -73.966958]],
#  [[40.746967, -74.00106], [40.791435, -73.944382]],
#  [[40.783215, -73.95287], [40.772352, -73.955827]],
#  [[40.75334, -73.969712], [40.724857, -73.99033]]]

# %%
print(lat1.iloc[0],lon1.iloc[0])
print(lat2.iloc[0],lon2.iloc[0])
# Out:
# 40.583785 -73.239712
# 40.572868 -73.474126

# %%
# line_coordinates = [
#     [40.750242, -73.991332], 
#     [40.77996, -73.957297]
# ]

# line = folium.PolyLine(locations=line_coordinates, color='blue', weight=3, opacity=0.8)

# line.add_to(map1)

# map1

# %%
# for i,j in data:
#     print([i,j])

# %%
for i,j in data:
    line = folium.PolyLine(locations=[i,j], color='blue', weight=3, opacity=0.8)
    line.add_to(map1)

map1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f3bcf9aec4ba461bf75979352852d0bd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f3bcf9aec4ba461bf75979352852d0bd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f3bcf9aec4ba461bf75979352852d0bd = L.map(
#                 &quot;map_f3bcf9aec4ba461bf75979352852d0bd&quot;,
#                 {
#                     center: [40.721319, -73.844311],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b8088bab5e20a57a3948b6c52fa534f5 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b8088bab5e20a57a3948b6c52fa534f5.addTo(map_f3bcf9aec4ba461bf75979352852d0bd);
#
#
#             tile_layer_b8088bab5e20a57a3948b6c52fa534f5.addTo(map_f3bcf9aec4ba461bf75979352852d0bd);
#
#
#             var marker_597163335155aacd65cab45f5200cd8c = L.marker(
#                 [40.583785, -73.239712],
#                 {
# }
#             ).addTo(map_f3bcf9aec4ba461bf75979352852d0bd);
#
#
#             var icon_a53c8c0e9bb8548abd757659d4156e1e = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_597163335155aacd65cab45f5200cd8c.setIcon(icon_a53c8c0e9bb8548abd757659d4156e1e);
#
#
#             marker_597163335155aacd65cab45f5200cd8c.bindTooltip(
#                 `&lt;div&gt;
#                      40.583785 -73.239712
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_451ba97311938d4fd4275fa34ebb76c4 = L.marker(
#                 [40.741693, -73.993871],
#                 {
# }
#             ).addTo(map_f3bcf9aec4ba461bf75979352852d0bd);
#
#
#             var icon_44228a20c2435b3957af31c54209074b = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_451ba97311938d4fd4275fa34ebb76c4.setIcon(icon_44228a20c2435b3957af31c54209074b);
#
#
#             marker_451ba97311938d4fd4275fa34ebb76c4.bindTooltip(
#                 `&lt;div&gt;
#                      40.741693 -73.993871
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_0a8af3337626b79029c74e782dc05eaa = L.marker(
#                 [40.72016907, -74.00856781],
#                 {
# }
#             ).addTo(map_f3bcf9aec4ba461bf75979352852d0bd);
#
#
#             var icon_84299930d2320d5e0407ab8b26ff3736 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_0a8af3337626b79029c74e782dc05eaa.setIcon(icon_84299930d2320d5e0407ab8b26ff3736);
#
#
#             marker_0a8af3337626b79029c74e782dc05eaa.bindTooltip(
#                 `&lt;div&gt;
#                      40.72016907 -74.00856781
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_f41aec0ca787f8cd504ab645c5ccad84 = L.marker(
#                 [40.755273, -73.968208],
#                 {
# }
#             ).addTo(map_f3bcf9aec4ba461bf75979352852d0bd);
#
#
#             var icon_3d2de451dec7fbc31104f0aceec2a267 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_f41aec0ca787f8cd504ab645c5ccad84.setIcon(icon_3d2de451dec7fbc31104f0aceec2a267);
#
#
#             marker_f41aec0ca787f8cd504ab645c5ccad84.bindTooltip(
#                 `&lt;div&gt;
#                      40.755273 -73.968208
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_4822ff12fd8cff14ed4c0060234553be = L.marker(
#                 [40.767133, -73.98181],
#                 {
# }
#             ).addTo(map_f3bcf9aec4ba461bf75979352852d0bd);
#
#
#             var icon_d79f3811ca142ff4714273d5b4389aab = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;

# %%
df.head()
# Out:
#         id  amount                  datetime  lon_pickup  lat_pickup  \
# 0  26:21.0     4.5 2009-06-15 17:26:21+00:00  -73.844311   40.721319
# 1  52:16.0    16.9 2010-01-05 16:52:16+00:00  -74.016048   40.711303
# 2  35:00.0     5.7 2011-08-18 00:35:00+00:00  -73.982738   40.761270
# 3  30:42.0     7.7 2012-04-21 04:30:42+00:00  -73.987130   40.733143
# 4  51:00.0     5.3 2010-03-09 07:51:00+00:00  -73.968095   40.768008
#
#     lon_drop   lat_drop  passcount    Yr  Qtr  Month  Day  Hour  DayofWeek  \
# 0 -73.841610  40.712278          1  2009    2      6   15    17          0
# 1 -73.979268  40.782004          1  2010    1      1    5    16          1
# 2 -73.991242  40.750562          2  2011    3      8   18     0          3
# 3 -73.991567  40.758092          1  2012    2      4   21     4          5
# 4 -73.956655  40.783762          1  2010    1      3    9     7          1
#
#    IsWeekend  Hr_Qtr Hr_Qtr1  Euclidean_Dist  Manhattan_Dist  Haversine_Dist
# 0          0       3       3        0.009436        0.011742        1.030764
# 1          0       3       3        0.079696        0.107481        8.450134
# 2          0       4     NaN        0.013674        0.019212        1.389525
# 3          1       1       1        0.025340        0.029386        2.799270
# 4          0       2       2        0.019470        0.027194        1.999157

# %%
df.describe()  # amount, passcount, lat,lon
# Out:
#              amount    lon_pickup    lat_pickup      lon_drop      lat_drop  \
# count  49825.000000  49825.000000  49825.000000  49825.000000  49825.000000
# mean      11.373212    -73.960844     40.747937    -73.964510     40.748190
# std        9.693602      0.109584      0.039964      0.092088      0.043295
# min        0.010000    -75.423848     40.583785    -84.654241     40.572868
# 25%        6.000000    -73.992066     40.734890    -73.991151     40.734378
# 50%        8.500000    -73.981838     40.752685    -73.980087     40.753375
# 75%       12.500000    -73.967145     40.767363    -73.963620     40.768162
# max      200.000000    -73.239712     43.098708    -73.474126     43.415190
#
#           passcount            Yr           Qtr         Month           Day  \
# count  49825.000000  49825.000000  49825.000000  49825.000000  49825.000000
# mean       1.673437   2011.740151      2.423663      6.275946     15.671631
# std        1.287799      1.865203      1.121367      3.460644      8.660797
# min        1.000000   2009.000000      1.000000      1.000000      1.000000
# 25%        1.000000   2010.000000      1.000000      3.000000      8.000000
# 50%        1.000000   2012.000000      2.000000      6.000000     16.000000
# 75%        2.000000   2013.000000      3.000000      9.000000     23.000000
# max        6.000000   2015.000000      4.000000     12.000000     31.000000
#
#                Hour     DayofWeek     IsWeekend        Hr_Qtr  Euclidean_Dist  \
# count  49825.000000  49825.000000  49825.000000  49825.000000    49825.000000
# mean      13.487807      3.029945      0.283051      2.825730        0.039518
# std        6.508598      1.957200      0.450485      1.002384        0.073428
# min        0.000000      0.000000      0.000000      1.000000        0.000000
# 25%        9.000000      1.000000      0.000000      2.000000        0.013051
# 50%       14.000000      3.000000      0.000000      3.000000        0.022344
# 75%       19.000000      5.000000      1.000000      4.000000        0.041002
# max       23.000000      6.000000      1.000000      4.000000       10.661284
#
#        Manhattan_Dist  Haversine_Dist
# count    49825.000000    49825.000000
# mean         0.049843        3.782257
# std          0.083408        6.406780
# min          0.000000        0.000000
# 25%          0.016690        1.280583
# 50%          0.028739        2.211265
# 75%          0.053869        4.144702
# max         10.837566      898.809128

# %% [markdown]
# #### Distance should not be 0
#
# Reasons
# 1) Same pickup and drop locations = Round trip rides

# %%
print(df[df['Euclidean_Dist']==0].shape)
print(df[df['Manhattan_Dist']==0].shape)
print(df[df['Haversine_Dist']==0].shape)
# Out:
# (520, 20)
# (520, 20)
# (520, 20)

# %% [markdown]
# #### Records where pickup location is same as drop location

# %%
round_trip = df[(df['lat_pickup']==df['lat_drop']) & (df['lon_pickup']==df['lon_drop'])]
round_trip.shape
# Out:
# (520, 20)

# %%
df.shape
# Out:
# (49825, 20)

# %%
49825-520
# Out:
# 49305

# %%
df2 = df.copy()

# %%
df = df[(df['Euclidean_Dist']>0) | (df['Manhattan_Dist']>0) | (df['Haversine_Dist']>0)]
df.shape
# Out:
# (49305, 20)

# %% [markdown]
# ### EDA

# %%
df.columns
# Out:
# Index(['id', 'amount', 'datetime', 'lon_pickup', 'lat_pickup', 'lon_drop',
#        'lat_drop', 'passcount', 'Yr', 'Qtr', 'Month', 'Day', 'Hour',
#        'DayofWeek', 'IsWeekend', 'Hr_Qtr', 'Hr_Qtr1', 'Euclidean_Dist',
#        'Manhattan_Dist', 'Haversine_Dist'],
#       dtype='object')

# %%
cat_cols = ['passcount','Yr', 'Qtr', 'Month', 'Day', 'Hour',
            'DayofWeek', 'IsWeekend', 'Hr_Qtr']
num_cols = ['amount','Euclidean_Dist','Manhattan_Dist', 'Haversine_Dist']

# %% [markdown]
# #### Univariate - Cat cols

# %%
plt.figure(figsize=(12,25))
for i in range(len(cat_cols)):
    plt.subplot(5,2,i+1)
    ax = sns.countplot(x=df[cat_cols[i]])
    ax.bar_label(ax.containers[0])
    plt.title(f'Countplot for {cat_cols[i]}')
plt.show()

# %% [markdown]
# #### Inferences
# <pre>
# 1) Peak Hour = 6-7pm
# 2) Peak Qtr = 2 and 1
# 3) Months with most rides = 4,5,6,3,2,1
# 4) Most busy days for rides = Fri and Sat
# 5) Peak Hr Qtr= 4 and 3
# </pre>

# %% [markdown]
# #### Univariate - Num cols

# %%
plt.figure(figsize=(12,10))
for i in range(len(num_cols)):
    plt.subplot(2,2,i+1)
    sns.kdeplot(x=df[num_cols[i]])
    plt.title(f'KDEPlot for {num_cols[i]}')
plt.show()

# %%
df.columns
# Out:
# Index(['id', 'amount', 'datetime', 'lon_pickup', 'lat_pickup', 'lon_drop',
#        'lat_drop', 'passcount', 'Yr', 'Qtr', 'Month', 'Day', 'Hour',
#        'DayofWeek', 'IsWeekend', 'Hr_Qtr', 'Hr_Qtr1', 'Euclidean_Dist',
#        'Manhattan_Dist', 'Haversine_Dist'],
#       dtype='object')

# %%
cols = ['Qtr','Month','Hour','DayofWeek','IsWeekend']

plt.figure(figsize=(12,15))
for i in range(len(cols)):
    plt.subplot(3,2,i+1)
    ax = sns.barplot(x=df[cols[i]],y=df['amount'],errorbar=('ci',0))  # mean amount
    ax.bar_label(ax.containers[0])
    plt.title(f'Mean Fare Amount for {cols[i]}')
plt.show()

# %% [markdown]
# #### Outlier Treatment

# %%
a1 = df.describe(percentiles=[0.01,0.02,0.05,0.95,0.98,0.99]).T
a1 = a1.iloc[:,3:]
a1
# Out:
#                          min           1%           2%           5%  \
# amount          1.000000e-02     3.300000     3.700000     4.100000
# lon_pickup     -7.542385e+01   -74.014345   -74.010426   -74.006815
# lat_pickup      4.058378e+01    40.583785    40.583785    40.702374
# lon_drop       -8.465424e+01   -74.015077   -74.011728   -74.007271
# lat_drop        4.057287e+01    40.572868    40.572868    40.686393
# passcount       1.000000e+00     1.000000     1.000000     1.000000
# Yr              2.009000e+03  2009.000000  2009.000000  2009.000000
# Qtr             1.000000e+00     1.000000     1.000000     1.000000
# Month           1.000000e+00     1.000000     1.000000     1.000000
# Day             1.000000e+00     1.000000     1.000000     2.000000
# Hour            0.000000e+00     0.000000     0.000000     1.000000
# DayofWeek       0.000000e+00     0.000000     0.000000     0.000000
# IsWeekend       0.000000e+00     0.000000     0.000000     0.000000
# Hr_Qtr          1.000000e+00     1.000000     1.000000     1.000000
# Euclidean_Dist  1.000000e-06     0.002454     0.004232     0.006377
# Manhattan_Dist  1.000000e-06     0.003084     0.005288     0.008005
# Haversine_Dist  8.436798e-05     0.243767     0.415834     0.627265
#
#                         50%          95%          98%          99%  \
# amount             8.500000    30.500000    45.830000    52.000000
# lon_pickup       -73.981867   -73.872122   -73.239712   -73.239712
# lat_pickup        40.752694    40.787722    40.799303    40.806796
# lon_drop         -73.980102   -73.874204   -73.474126   -73.474126
# lat_drop          40.753392    40.793980    40.810033    40.832131
# passcount          1.000000     5.000000     5.000000     6.000000
# Yr              2012.000000  2015.000000  2015.000000  2015.000000
# Qtr                2.000000     4.000000     4.000000     4.000000
# Month              6.000000    12.000000    12.000000    12.000000
# Day               16.000000    29.000000    30.000000    31.000000
# Hour              14.000000    22.000000    23.000000    23.000000
# DayofWeek          3.000000     6.000000     6.000000     6.000000
# IsWeekend          0.000000     1.000000     1.000000     1.000000
# Hr_Qtr             3.000000     4.000000     4.000000     4.000000
# Euclidean_Dist     0.022582     0.140868     0.234668     0.234668
# Manhattan_Dist     0.029096     0.181392     0.245331     0.305851
# Haversine_Dist     2.233332    13.367890    19.834490    20.744976
#
#                         max
# amount           200.000000
# lon_pickup       -73.239712
# lat_pickup        43.098708
# lon_drop         -73.474126
# lat_drop          43.415190
# passcount          6.000000
# Yr              2015.000000
# Qtr                4.000000
# Month             12.000000
# Day               31.000000
# Hour              23.000000
# DayofWeek          6.000000
# IsWeekend          1.000000
# Hr_Qtr             4.000000
# Euclidean_Dist    10.661284
# Manhattan_Dist    10.837566
# Haversine_Dist   898.809128

# %%
print(df[df['Euclidean_Dist']>0.234668].shape)
print(df[df['Manhattan_Dist']>0.305851].shape)
print(df[df['Haversine_Dist']>20.744976].shape)
# Out:
# (1277, 20)
# (494, 20)
# (494, 20)

# %%
df['Euclidean_Dist'] = np.where(df['Euclidean_Dist']>0.234668,0.234668,df['Euclidean_Dist'])
df['Manhattan_Dist'] = np.where(df['Manhattan_Dist']>0.305851,0.305851,df['Manhattan_Dist'])
df['Haversine_Dist'] = np.where(df['Haversine_Dist']>20.744976,20.744976,df['Haversine_Dist'])

# %%
a1 = df.describe(percentiles=[0.01,0.02,0.05,0.95,0.98,0.99]).T
a1 = a1.iloc[:,3:]
a1
# Out:
#                          min           1%           2%           5%  \
# amount          1.000000e-02     3.300000     3.700000     4.100000
# lon_pickup     -7.542385e+01   -74.014345   -74.010426   -74.006815
# lat_pickup      4.058378e+01    40.583785    40.583785    40.702374
# lon_drop       -8.465424e+01   -74.015077   -74.011728   -74.007271
# lat_drop        4.057287e+01    40.572868    40.572868    40.686393
# passcount       1.000000e+00     1.000000     1.000000     1.000000
# Yr              2.009000e+03  2009.000000  2009.000000  2009.000000
# Qtr             1.000000e+00     1.000000     1.000000     1.000000
# Month           1.000000e+00     1.000000     1.000000     1.000000
# Day             1.000000e+00     1.000000     1.000000     2.000000
# Hour            0.000000e+00     0.000000     0.000000     1.000000
# DayofWeek       0.000000e+00     0.000000     0.000000     0.000000
# IsWeekend       0.000000e+00     0.000000     0.000000     0.000000
# Hr_Qtr          1.000000e+00     1.000000     1.000000     1.000000
# Euclidean_Dist  1.000000e-06     0.002454     0.004232     0.006377
# Manhattan_Dist  1.000000e-06     0.003084     0.005288     0.008005
# Haversine_Dist  8.436798e-05     0.243767     0.415834     0.627265
#
#                         50%          95%          98%          99%  \
# amount             8.500000    30.500000    45.830000    52.000000
# lon_pickup       -73.981867   -73.872122   -73.239712   -73.239712
# lat_pickup        40.752694    40.787722    40.799303    40.806796
# lon_drop         -73.980102   -73.874204   -73.474126   -73.474126
# lat_drop          40.753392    40.793980    40.810033    40.832131
# passcount          1.000000     5.000000     5.000000     6.000000
# Yr              2012.000000  2015.000000  2015.000000  2015.000000
# Qtr                2.000000     4.000000     4.000000     4.000000
# Month              6.000000    12.000000    12.000000    12.000000
# Day               16.000000    29.000000    30.000000    31.000000
# Hour              14.000000    22.000000    23.000000    23.000000
# DayofWeek          3.000000     6.000000     6.000000     6.000000
# IsWeekend          0.000000     1.000000     1.000000     1.000000
# Hr_Qtr             3.000000     4.000000     4.000000     4.000000
# Euclidean_Dist     0.022582     0.140868     0.234668     0.234668
# Manhattan_Dist     0.029096     0.181392     0.245331     0.305849
# Haversine_Dist     2.233332    13.367890    19.834490    20.744936
#
#                         max
# amount           200.000000
# lon_pickup       -73.239712
# lat_pickup        43.098708
# lon_drop         -73.474126
# lat_drop          43.415190
# passcount          6.000000
# Yr              2015.000000
# Qtr                4.000000
# Month             12.000000
# Day               31.000000
# Hour              23.000000
# DayofWeek          6.000000
# IsWeekend          1.000000
# Hr_Qtr             4.000000
# Euclidean_Dist     0.234668
# Manhattan_Dist     0.305851
# Haversine_Dist    20.744976

# %%
df['amount'] = np.where(df['amount']>52,52,df['amount'])
df['amount'] = np.where(df['amount']<3.3000,3.3000,df['amount'])

# %%
a1 = df.describe(percentiles=[0.01,0.02,0.05,0.95,0.98,0.99]).T
a1 = a1.iloc[:,3:]
a1
# Out:
#                          min           1%           2%           5%  \
# amount          3.300000e+00     3.300000     3.700000     4.100000
# lon_pickup     -7.542385e+01   -74.014345   -74.010426   -74.006815
# lat_pickup      4.058378e+01    40.583785    40.583785    40.702374
# lon_drop       -8.465424e+01   -74.015077   -74.011728   -74.007271
# lat_drop        4.057287e+01    40.572868    40.572868    40.686393
# passcount       1.000000e+00     1.000000     1.000000     1.000000
# Yr              2.009000e+03  2009.000000  2009.000000  2009.000000
# Qtr             1.000000e+00     1.000000     1.000000     1.000000
# Month           1.000000e+00     1.000000     1.000000     1.000000
# Day             1.000000e+00     1.000000     1.000000     2.000000
# Hour            0.000000e+00     0.000000     0.000000     1.000000
# DayofWeek       0.000000e+00     0.000000     0.000000     0.000000
# IsWeekend       0.000000e+00     0.000000     0.000000     0.000000
# Hr_Qtr          1.000000e+00     1.000000     1.000000     1.000000
# Euclidean_Dist  1.000000e-06     0.002454     0.004232     0.006377
# Manhattan_Dist  1.000000e-06     0.003084     0.005288     0.008005
# Haversine_Dist  8.436798e-05     0.243767     0.415834     0.627265
#
#                         50%          95%          98%          99%  \
# amount             8.500000    30.500000    45.830000    52.000000
# lon_pickup       -73.981867   -73.872122   -73.239712   -73.239712
# lat_pickup        40.752694    40.787722    40.799303    40.806796
# lon_drop         -73.980102   -73.874204   -73.474126   -73.474126
# lat_drop          40.753392    40.793980    40.810033    40.832131
# passcount          1.000000     5.000000     5.000000     6.000000
# Yr              2012.000000  2015.000000  2015.000000  2015.000000
# Qtr                2.000000     4.000000     4.000000     4.000000
# Month              6.000000    12.000000    12.000000    12.000000
# Day               16.000000    29.000000    30.000000    31.000000
# Hour              14.000000    22.000000    23.000000    23.000000
# DayofWeek          3.000000     6.000000     6.000000     6.000000
# IsWeekend          0.000000     1.000000     1.000000     1.000000
# Hr_Qtr             3.000000     4.000000     4.000000     4.000000
# Euclidean_Dist     0.022582     0.140868     0.234668     0.234668
# Manhattan_Dist     0.029096     0.181392     0.245331     0.305849
# Haversine_Dist     2.233332    13.367890    19.834490    20.744936
#
#                         max
# amount            52.000000
# lon_pickup       -73.239712
# lat_pickup        43.098708
# lon_drop         -73.474126
# lat_drop          43.415190
# passcount          6.000000
# Yr              2015.000000
# Qtr                4.000000
# Month             12.000000
# Day               31.000000
# Hour              23.000000
# DayofWeek          6.000000
# IsWeekend          1.000000
# Hr_Qtr             4.000000
# Euclidean_Dist     0.234668
# Manhattan_Dist     0.305851
# Haversine_Dist    20.744976

# %%
ax = sns.barplot(x=df['passcount'],y=df['amount'],errorbar=('ci',0))
ax.bar_label(ax.containers[0])
plt.show()

# %% [markdown]
# #### Encoding
#
# Not required

# %% [markdown]
# #### Select x and y

# %%
df.columns
# Out:
# Index(['id', 'amount', 'datetime', 'lon_pickup', 'lat_pickup', 'lon_drop',
#        'lat_drop', 'passcount', 'Yr', 'Qtr', 'Month', 'Day', 'Hour',
#        'DayofWeek', 'IsWeekend', 'Hr_Qtr', 'Hr_Qtr1', 'Euclidean_Dist',
#        'Manhattan_Dist', 'Haversine_Dist'],
#       dtype='object')

# %%
x = df[['passcount', 'Yr', 'Qtr', 'Month', 'Day', 'Hour',
       'DayofWeek', 'IsWeekend', 'Hr_Qtr', 'Euclidean_Dist',
       'Manhattan_Dist', 'Haversine_Dist']]
y = df['amount']

# %% [markdown]
# #### Split data into train and test

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3,random_state=42)
print(x_train.shape,x_test.shape)
print(y_train.shape,y_test.shape)
# Out:
# (34513, 12) (14792, 12)
# (34513,) (14792,)

# %%
from sklearn.metrics import *

# %%
def eval_model(ytest,ypred):
    mse = mean_squared_error(ytest,ypred) 
    rmse = np.sqrt(mse)
    mae = mean_absolute_error(ytest,ypred)
    r2 = r2_score(ytest,ypred)
    res = {'MSE':mse,'RMSE':rmse,'MAE':mae,'R2':r2}
    print('MAE',mae,'MSE',mse,'RMSE',rmse,'R2_Score',r2)
    return res

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor

# %%
lr1 = LinearRegression()   # Lienar Reg model instance
lr1.fit(x_train,y_train) 
print('Train score',lr1.score(x_train,y_train))  # Train R2 Score
print('Test score',lr1.score(x_test,y_test))
# Out:
# Train score 0.6303771206564399
# Test score 0.6157929119487516

# %%
ypred_lr1 = lr1.predict(x_test)

lr1_res = eval_model(y_test,ypred_lr1)
# Out:
# MAE 3.110658388808824 MSE 30.731109148345258 RMSE 5.543564660788693 R2_Score 0.6157929119487516

# %% [markdown]
# ### 2) DT reg

# %%
from sklearn.tree import DecisionTreeClassifier, plot_tree,export_text

# %%
dt1 = DecisionTreeRegressor(max_depth=7,min_samples_split=8)
dt1.fit(x_train,y_train)
print('Train score',dt1.score(x_train,y_train))  # Train R2 Score
print('Test score',dt1.score(x_test,y_test))
# Out:
# Train score 0.819700198351574
# Test score 0.7714246982360089

# %%
ypred_dt1 = dt1.predict(x_test)
dt1_res = eval_model(y_test,ypred_dt1)
# Out:
# MAE 2.2153430384577844 MSE 18.28277708970377 RMSE 4.275836419895383 R2_Score 0.7714246982360089

# %%
rf1  = RandomForestRegressor(n_estimators=80,max_depth=7,min_samples_split=8)
rf1.fit(x_train,y_train)
0print('Train score',rf1.score(x_train,y_train))  # Train R2 Score
print('Test score',rf1.score(x_test,y_test))
# Out:
# Train score 0.8315856054691175
# Test score 0.7989543040488564

# %%
ypred_rf1 = rf1.predict(x_test)
rf1_res = eval_model(y_test,ypred_rf1)
# Out:
# MAE 2.1369165025279897 MSE 16.080799699498296 RMSE 4.010087243377417 R2_Score 0.7989543040488564

# %%
all_res = pd.DataFrame([lr1_res,dt1_res,rf1_res],index=['Lin_Reg','Dt_Reg','Rf_Reg'])
all_res
# Out:
#                MSE      RMSE       MAE        R2
# Lin_Reg  30.731109  5.543565  3.110658  0.615793
# Dt_Reg   18.282777  4.275836  2.215343  0.771425
# Rf_Reg   16.080800  4.010087  2.136917  0.798954

# %%
from sklearn.tree import plot_tree,export_text

# %%
fn = x_train.columns
cn = y_train

# %%
plt.figure(figsize=(30,30))
plot_tree(rf1.estimators_[0],feature_names=fn,class_names=cn,filled=True)
plt.show()

# %% [markdown]
# ### Generate Decision Rules

# %%
print(export_text(rf1.estimators_[0],feature_names = x_train.columns.to_list()))
# Out:
# |--- Euclidean_Dist <= 0.07
# |   |--- Euclidean_Dist <= 0.03
# |   |   |--- Euclidean_Dist <= 0.02
# |   |   |   |--- Haversine_Dist <= 0.09
# |   |   |   |   |--- Manhattan_Dist <= 0.00
# |   |   |   |   |   |--- Day <= 4.50
# |   |   |   |   |   |   |--- value: [3.30]
# |   |   |   |   |   |--- Day >  4.50
# |   |   |   |   |   |   |--- Month <= 8.50
# |   |   |   |   |   |   |   |--- value: [45.74]
# |   |   |   |   |   |   |--- Month >  8.50
# |   |   |   |   |   |   |   |--- value: [19.09]
# |   |   |   |   |--- Manhattan_Dist >  0.00
# |   |   |   |   |   |--- Haversine_Dist <= 0.09
# |   |   |   |   |   |   |--- passcount <= 1.50
# |   |   |   |   |   |   |   |--- value: [12.37]
# |   |   |   |   |   |   |--- passcount >  1.50
# |   |   |   |   |   |   |   |--- value: [22.09]
# |   |   |   |   |   |--- Haversine_Dist >  0.09
# |   |   |   |   |   |   |--- value: [40.03]
# |   |   |   |--- Haversine_Dist >  0.09
# |   |   |   |   |--- Haversine_Dist <= 0.98
# |   |   |   |   |   |--- Haversine_Dist <= 0.28
# |   |   |   |   |   |   |--- Day <= 4.50
# |   |   |   |   |   |   |   |--- value: [15.89]
# |   |   |   |   |   |   |--- Day >  4.50
# |   |   |   |   |   |   |   |--- value: [6.64]
# |   |   |   |   |   |--- Haversine_Dist >  0.28
# |   |   |   |   |   |   |--- Euclidean_Dist <= 0.01
# |   |   |   |   |   |   |   |--- value: [4.74]
# |   |   |   |   |   |   |--- Euclidean_Dist >  0.01
# |   |   |   |   |   |   |   |--- value: [5.54]
# |   |   |   |   |--- Haversine_Dist >  0.98
# |   |   |   |   |   |--- Yr <= 2012.50
# |   |   |   |   |   |   |--- Euclidean_Dist <= 0.01
# |   |   |   |   |   |   |   |--- value: [5.47]
# |   |   |   |   |   |   |--- Euclidean_Dist >  0.01
# |   |   |   |   |   |   |   |--- value: [6.22]
# |   |   |   |   |   |--- Yr >  2012.50
# |   |   |   |   |   |   |--- Haversine_Dist <= 0.98
# |   |   |   |   |   |   |   |--- value: [19.00]
# |   |   |   |   |   |   |--- Haversine_Dist >  0.98
# |   |   |   |   |   |   |   |--- value: [6.91]
# |   |   |--- Euclidean_Dist >  0.02
# |   |   |   |--- Euclidean_Dist <= 0.02
# |   |   |   |   |--- Yr <= 2012.50
# |   |   |   |   |   |--- Euclidean_Dist <= 0.02
# |   |   |   |   |   |   |--- Haversine_Dist <= 1.93
# |   |   |   |   |   |   |   |--- value: [6.84]
# |   |   |   |   |   |   |--- Haversine_Dist >  1.93
# |   |   |   |   |   |   |   |--- value: [7.60]
# |   |   |   |   |   |--- Euclidean_Dist >  0.02
# |   |   |   |   |   |   |--- Manhattan_Dist <= 0.03
# |   |   |   |   |   |   |   |--- value: [8.25]
# |   |   |   |   |   |   |--- Manhattan_Dist >  0.03
# |   |   |   |   |   |   |   |--- value: [7.39]
# |   |   |   |   |--- Yr >  2012.50
# |   |   |   |   |   |--- Hour <= 7.50
# |   |   |   |   |   |   |--- Hour <= 0.50
# |   |   |   |   |   |   |   |--- value: [8.48]
# |   |   |   |   |   |   |--- Hour >  0.50
# |   |   |   |   |   |   |   |--- value: [7.46]
# |   |   |   |   |   |--- Hour >  7.50
# |   |   |   |   |   |   |--- Hour <= 18.50
# |   |   |   |   |   |   |   |--- value: [9.22]
# |   |   |   |   |   |   |--- Hour >  18.50
# |   |   |   |   |   |   |   |--- value: [8.26]
# |   |   |   |--- Euclidean_Dist >  0.02
# |   |   |   |   |--- Yr <= 2012.50
# |   |   |   |   |   |--- Haversine_Dist <= 3.07
# |   |   |   |   |   |   |--- Euclidean_Dist <= 0.02
# |   |   |   |   |   |   |   |--- value: [8.14]
# |   |   |   |   |   |   |--- Euclidean_Dist >  0.02
# |   |   |   |   |   |   |   |--- value: [8.89]
# |   |   |   |   |   |--- Haversine_Dist >  3.07
# |   |   |   |   |   |   |--- Day <= 30.50
# |   |   |   |   |   |   |   |--- value: [10.50]
# |   |   |   |   |   |   |--- Day >  30.50
# |   |   |   |   |   |   |   |--- value: [15.60]
# |   |   |   |   |--- Yr >  2012.50
# |   |   |   |   |   |--- Euclidean_Dist <= 0.03
# |   |   |   |   |   |   |--- Manhattan_Dist <= 0.03
# |   |   |   |   |   |   |   |--- value: [10.81]
# |   |   |   |   |   |   |--- Manhattan_Dist >  0.03
# |   |   |   |   |   |   |   |--- value: [9.70]
# |   |   |   |   |   |--- Euclidean_Dist >  0.03
# |   |   |   |   |   |   |--- Manhattan_Dist <= 0.04
# |   |   |   |   |   |   |   |--- value: [12.08]
# |   |   |   |   |   |   |--- Manhattan_Dist >  0.04
# |   |   |   |   |   |   |   |--- value: [10.42]
# |   |--- Euclidean_Dist >  0.03
# |   |   |--- Euclidean_Dist <= 0.05
# |   |   |   |--- Yr <= 2012.50
# |   |   |   |   |--- Euclidean_Dist <= 0.04
# |   |   |   |   |   |--- Month <= 8.50
# |   |   |   |   |   |   |--- Euclidean_Dist <= 0.03
# |   |   |   |   |   |   |   |--- value: [9.62]
# |   |   |   |   |   |   |--- Euclidean_Dist >  0.03
# |   |   |   |   |   |   |   |--- value: [10.45]
# |   |   |   |   |   |--- Month >  8.50
# |   |   |   |   |   |   |--- Yr <= 2011.50
# |   |   |   |   |   |   |   |--- value: [10.25]
# |   |   |   |   |   |   |--- Yr >  2011.50
# |   |   |   |   |   |   |   |--- value: [12.84]
# |   |   |   |   |--- Euclidean_Dist >  0.04
# |   |   |   |   |   |--- Manhattan_Dist <= 0.05
# |   |   |   |   |   |   |--- Manhattan_Dist <= 0.05
# |   |   |   |   |   |   |   |--- value: [12.87]
# |   |   |   |   |   |   |--- Manhattan_Dist >  0.05
# |   |   |   |   |   |   |   |--- value: [22.07]
# |   |   |   |   |   |--- Manhattan_Dist >  0.05
# |   |   |   |   |   |   |--- Euclidean_Dist <= 0.04
# |   |   |   |   |   |   |   |--- value: [10.83]
# |   |   |   |   |   |   |--- Euclidean_Dist >  0.04
# |   |   |   |   |   |   |   |--- value: [12.06]
# |   |   |   |--- Yr >  2012.50
# |   |   |   |   |--- Euclidean_Dist <= 0.04
# |   |   |   |   |   |--- Haversine_Dist <= 3.73
# |   |   |   |   |   |   |--- Hour <= 7.50
# |   |   |   |   |   |   |   |--- value: [10.99]
# |   |   |   |   |   |   |--- Hour >  7.50
# |   |   |   |   |   |   |   |--- value: [12.22]
# |   |   |   |   |   |--- Haversine_Dist >  3.73
# |   |   |   |   |   |   |--- Manhattan_Dist <= 0.04
# |   |   |   |   |   |   |   |--- value: [15.64]
# |   |   |   |   |   |   |--- Manhattan_Dist >  0.04
# |   |   |   |   |   |   |   |--- value: [12.49]
# |   |   |   |   |--- Euclidean_Dist >  0.04
# |   |   |   |   |   |--- Hour <= 8.50
# |   |   |   |   |   |   |--- Hour <= 2.50
# |   |   |   |   |   |   |   |--- value: [14.76]
# |   |   |   |   |   |   |--- Hour >  2.50
# |   |   |   |   |   |   |   |--- value: [12.70]
# |   |   |   |   |   |--- Hour >  8.50
# |   |   |   |   |   |   |--- Hour <= 15.50
# |   |   |   |   |   |   |   |--- value: [16.29]
# |   |   |   |   |   |   |--- Hour >  15.50
# |   |   |   |   |   |   |   |--- value: [14.53]
# |   |   |--- Euclidean_Dist >  0.05
# |   |   |   |--- Yr <= 2012.50
# |   |   |   |   |--- Euclidean_Dist <= 0.06
# |   |   |   |   |   |--- Haversine_Dist <= 4.33
# |   |   |   |   |   |   |--- Day <= 28.00
# |   |   |   |   |   |   |   |--- value: [14.33]
# |   |   |   |   |   |   |--- Day >  28.00
# |   |   |   |   |   |   |   |--- value: [41.48]
# |   |   |   |   |   |--- Haversine_Dist >  4.33
# |   |   |   |   |   |   |--- Haversine_Dist <= 5.37
# |   |   |   |   |   |   |   |--- value: [13.22]
# |   |   |   |   |   |   |--- Haversine_Dist >  5.37
# |   |   |   |   |   |   |   |--- value: [14.65]
# |   |   |   |   |--- Euclidean_Dist >  0.06
# |   |   |   |   |   |--- Manhattan_Dist <= 0.08
# |   |   |   |   |   |   |--- Haversine_Dist <= 6.49
# |   |   |   |   |   |   |   |--- value: [15.72]
# |   |   |   |   |   |   |--- Haversine_Dist >  6.49
# |   |   |   |   |   |   |   |--- value: [18.93]
# |   |   |   |   |   |--- Manhattan_Dist >  0.08
# |   |   |   |   |   |   |--- Yr <= 2011.50
# |   |   |   |   |   |   |   |--- value: [15.09]
# |   |   |   |   |   |   |--- Yr >  2011.50
# |   |   |   |   |   |   |   |--- value: [16.67]
# |   |   |   |--- Yr >  2012.50
# |   |   |   |   |--- Euclidean_Dist <= 0.05
# |   |   |   |   |   |--- passcount <= 5.50
# |   |   |   |   |   |   |--- Day <= 29.50
# |   |   |   |   |   |   |   |--- value: [15.94]
# |   |   |   |   |   |   |--- Day >  29.50
# |   |   |   |   |   |   |   |--- value: [20.46]
# |   |   |   |   |   |--- passcount >  5.50
# |   |   |   |   |   |   |--- value: [24.10]
# |   |   |   |   |--- Euclidean_Dist >  0.05
# |   |   |   |   |   |--- Hour <= 18.50
# |   |   |   |   |   |   |--- Hour <= 8.50
# |   |   |   |   |   |   |   |--- value: [18.01]
# |   |   |   |   |   |   |--- Hour >  8.50
# |   |   |   |   |   |   |   |--- value: [20.38]
# |   |   |   |   |   |--- Hour >  18.50
# |   |   |   |   |   |   |--- Day <= 18.50
# |   |   |   |   |   |   |   |--- value: [18.54]
# |   |   |   |   |   |   |--- Day >  18.50
# |   |   |   |   |   |   |   |--- value: [16.80]
# |--- Euclidean_Dist >  0.07
# |   |--- Manhattan_Dist <= 0.25
# |   |   |--- Haversine_Dist <= 19.49
# |   |   |   |--- Euclidean_Dist <= 0.10
# |   |   |   |   |--- Yr <= 2012.50
# |   |   |   |   |   |--- Euclidean_Dist <= 0.08
# |   |   |   |   |   |   |--- Hour <= 6.50
# |   |   |   |   |   |   |   |--- value: [16.29]
# |   |   |   |   |   |   |--- Hour >  6.50
# |   |   |   |   |   |   |   |--- value: [18.40]
# |   |   |   |   |   |--- Euclidean_Dist >  0.08
# |   |   |   |   |   |   |--- Manhattan_Dist <= 0.10
# |   |   |   |   |   |   |   |--- value: [25.42]
# |   |   |   |   |   |   |--- Manhattan_Dist >  0.10
# |   |   |   |   |   |   |   |--- value: [19.96]
# |   |   |   |   |--- Yr >  2012.50
# |   |   |   |   |   |--- Euclidean_Dist <= 0.08
# |   |   |   |   |   |   |--- Haversine_Dist <= 5.87
# |   |   |   |   |   |   |   |--- value: [52.00]
# |   |   |   |   |   |   |--- Haversine_Dist >  5.87
# |   |   |   |   |   |   |   |--- value: [21.58]
# |   |   |   |   |   |--- Euclidean_Dist >  0.08
# |   |   |   |   |   |   |--- Manhattan_Dist <= 0.10
# |   |   |   |   |   |   |   |--- value: [30.03]
# |   |   |   |   |   |   |--- Manhattan_Dist >  0.10
# |   |   |   |   |   |   |   |--- value: [25.34]
# |   |   |   |--- Euclidean_Dist >  0.10
# |   |   |   |   |--- Yr <= 2012.50
# |   |   |   |   |   |--- Euclidean_Dist <= 0.15
# |   |   |   |   |   |   |--- Euclidean_Dist <= 0.12
# |   |   |   |   |   |   |   |--- value: [26.62]
# |   |   |   |   |   |   |--- Euclidean_Dist >  0.12
# |   |   |   |   |   |   |   |--- value: [29.60]
# |   |   |   |   |   |--- Euclidean_Dist >  0.15
# |   |   |   |   |   |   |--- Euclidean_Dist <= 0.16
# |   |   |   |   |   |   |   |--- value: [33.99]
# |   |   |   |   |   |   |--- Euclidean_Dist >  0.16
# |   |   |   |   |   |   |   |--- value: [38.68]
# |   |   |   |   |--- Yr >  2012.50
# |   |   |   |   |   |--- Euclidean_Dist <= 0.13
# |   |   |   |   |   |   |--- Hour <= 4.50
# |   |   |   |   |   |   |   |--- value: [27.52]
# |   |   |   |   |   |   |--- Hour >  4.50
# |   |   |   |   |   |   |   |--- value: [34.12]
# |   |   |   |   |   |--- Euclidean_Dist >  0.13
# |   |   |   |   |   |   |--- Euclidean_Dist <= 0.18
# |   |   |   |   |   |   |   |--- value: [39.27]
# |   |   |   |   |   |   |--- Euclidean_Dist >  0.18
# |   |   |   |   |   |   |   |--- value: [48.87]
# |   |   |--- Haversine_Dist >  19.49
# |   |   |   |--- Month <= 4.50
# |   |   |   |   |--- Day <= 25.50
# |   |   |   |   |   |--- Day <= 23.50
# |   |   |   |   |   |   |--- DayofWeek <= 1.50
# |   |   |   |   |   |   |   |--- value: [6.36]
# |   |   |   |   |   |   |--- DayofWeek >  1.50
# |   |   |   |   |   |   |   |--- value: [8.47]
# |   |   |   |   |   |--- Day >  23.50
# |   |   |   |   |   |   |--- Hour <= 20.00
# |   |   |   |   |   |   |   |--- value: [9.09]
# |   |   |   |   |   |   |--- Hour >  20.00
# |   |   |   |   |   |   |   |--- value: [49.80]
# |   |   |   |   |--- Day >  25.50
# |   |   |   |   |   |--- Day <= 26.50
# |   |   |   |   |   |   |--- value: [31.70]
# |   |   |   |   |   |--- Day >  26.50
# |   |   |   |   |   |   |--- Month <= 3.50
# |   |   |   |   |   |   |   |--- value: [11.44]
# |   |   |   |   |   |   |--- Month >  3.50
# |   |   |   |   |   |   |   |--- value: [20.56]
# |   |   |   |--- Month >  4.50
# |   |   |   |   |--- Month <= 5.50
# |   |   |   |   |   |--- Day <= 17.00
# |   |   |   |   |   |   |--- Day <= 12.50
# |   |   |   |   |   |   |   |--- value: [15.82]
# |   |   |   |   |   |   |--- Day >  12.50
# |   |   |   |   |   |   |   |--- value: [41.33]
# |   |   |   |   |   |--- Day >  17.00
# |   |   |   |   |   |   |--- DayofWeek <= 1.50
# |   |   |   |   |   |   |   |--- value: [24.24]
# |   |   |   |   |   |   |--- DayofWeek >  1.50
# |   |   |   |   |   |   |   |--- value: [11.59]
# |   |   |   |   |--- Month >  5.50
# |   |   |   |   |   |--- Euclidean_Dist <= 0.22
# |   |   |   |   |   |   |--- value: [52.00]
# |   |   |   |   |   |--- Euclidean_Dist >  0.22
# |   |   |   |   |   |   |--- Yr <= 2014.50
# |   |   |   |   |   |   |   |--- value: [11.64]
# |   |   |   |   |   |   |--- Yr >  2014.50
# |   |   |   |   |   |   |   |--- value: [26.12]
# |   |--- Manhattan_Dist >  0.25
# |   |   |--- Euclidean_Dist <= 0.23
# |   |   |   |--- Euclidean_Dist <= 0.20
# |   |   |   |   |--- Manhattan_Dist <= 0.25
# |   |   |   |   |   |--- value: [48.60]
# |   |   |   |   |--- Manhattan_Dist >  0.25
# |   |   |   |   |   |--- Yr <= 2012.50
# |   |   |   |   |   |   |--- Haversine_Dist <= 17.77
# |   |   |   |   |   |   |   |--- value: [43.07]
# |   |   |   |   |   |   |--- Haversine_Dist >  17.77
# |   |   |   |   |   |   |   |--- value: [35.58]
# |   |   |   |   |   |--- Yr >  2012.50
# |   |   |   |   |   |   |--- Month <= 9.50
# |   |   |   |   |   |   |   |--- value: [43.27]
# |   |   |   |   |   |   |--- Month >  9.50
# |   |   |   |   |   |   |   |--- value: [50.50]
# |   |   |   |--- Euclidean_Dist >  0.20
# |   |   |   |   |--- Yr <= 2012.50
# |   |   |   |   |   |--- Hour <= 3.50
# |   |   |   |   |   |   |--- value: [31.23]
# |   |   |   |   |   |--- Hour >  3.50
# |   |   |   |   |   |   |--- Euclidean_Dist <= 0.23
# |   |   |   |   |   |   |   |--- value: [48.43]
# |   |   |   |   |   |   |--- Euclidean_Dist >  0.23
# |   |   |   |   |   |   |   |--- value: [45.29]
# |   |   |   |   |--- Yr >  2012.50
# |   |   |   |   |   |--- Manhattan_Dist <= 0.29
# |   |   |   |   |   |   |--- Manhattan_Dist <= 0.29
# |   |   |   |   |   |   |   |--- value: [51.78]
# |   |   |   |   |   |   |--- Manhattan_Dist >  0.29
# |   |   |   |   |   |   |   |--- value: [5.50]
# |   |   |   |   |   |--- Manhattan_Dist >  0.29
# |   |   |   |   |   |   |--- value: [52.00]
# |   |   |--- Euclidean_Dist >  0.23
# |   |   |   |--- Month <= 10.50
# |   |   |   |   |--- Day <= 14.50
# |   |   |   |   |   |--- passcount <= 1.50
# |   |   |   |   |   |   |--- Hr_Qtr <= 1.50
# |   |   |   |   |   |   |   |--- value: [6.63]
# |   |   |   |   |   |   |--- Hr_Qtr >  1.50
# |   |   |   |   |   |   |   |--- value: [41.06]
# |   |   |   |   |   |--- passcount >  1.50
# |   |   |   |   |   |   |--- DayofWeek <= 5.50
# |   |   |   |   |   |   |   |--- value: [49.85]
# |   |   |   |   |   |   |--- DayofWeek >  5.50
# |   |   |   |   |   |   |   |--- value: [28.85]
# |   |   |   |   |--- Day >  14.50
# |   |   |   |   |   |--- Manhattan_Dist <= 0.30
# |   |   |   |   |   |   |--- value: [49.50]
# |   |   |   |   |   |--- Manhattan_Dist >  0.30
# |   |   |   |   |   |   |--- Month <= 3.50
# |   |   |   |   |   |   |   |--- value: [25.85]
# |   |   |   |   |   |   |--- Month >  3.50
# |   |   |   |   |   |   |   |--- value: [36.21]
# |   |   |   |--- Month >  10.50
# |   |   |   |   |--- Yr <= 2010.50
# |   |   |   |   |   |--- value: [49.15]
# |   |   |   |   |--- Yr >  2010.50
# |   |   |   |   |   |--- value: [52.00]

# %% [markdown]
# #### Feat Importance

# %%
fimp = pd.DataFrame({'Feature':x_train.columns,'FImp':rf1.feature_importances_})
fimp = fimp.sort_values('FImp',ascending=False)
fimp
# Out:
#            Feature      FImp
# 9   Euclidean_Dist  0.786060
# 10  Manhattan_Dist  0.136856
# 11  Haversine_Dist  0.028681
# 1               Yr  0.023766
# 5             Hour  0.007226
# 4              Day  0.005813
# 3            Month  0.005146
# 6        DayofWeek  0.002755
# 0        passcount  0.001749
# 8           Hr_Qtr  0.001052
# 2              Qtr  0.000724
# 7        IsWeekend  0.000172

# %%
thresh = 0.001
imp_feat= fimp['Feature'][fimp['FImp']>thresh].values
imp_feat
# Out:
# array(['Euclidean_Dist', 'Manhattan_Dist', 'Haversine_Dist', 'Yr', 'Hour',
#        'Day', 'Month', 'DayofWeek', 'passcount', 'Hr_Qtr'], dtype=object)

# %% [markdown]
# ### Generating Model And Selecting Imp Feature

# %%
x2 = df[imp_feat]
y2 = df['amount']

# %%
rf2  = RandomForestRegressor(max_depth=7,min_samples_split=8)
rf2.fit(x_train,y_train)
print('Train score',rf2.score(x_train,y_train))  # Train R2 Score
print('Test score',rf2.score(x_test,y_test))
# Out:
# Train score 0.8315856499114851
# Test score 0.7993264749598237

# %%
ypred_rf2 = rf2.predict(x_test)
rf2_res = eval_model(y_test,ypred_rf2)
# Out:
# MAE 2.133316803145337 MSE 16.051031313535436 RMSE 4.00637383596881 R2_Score 0.7993264749598237
